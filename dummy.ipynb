# %%
from pymongo import MongoClient

client = MongoClient('mongodb://localhost:27017/')
db = client['dsa_problems']
collection = db['problems']

# %%
import json
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['dsa_problems']
collection = db['problems']

with open(r'C:\git repos\dsa_search_engine\dataset\djson\dp.json', 'r') as file:
    for line in file:
        # Strip whitespace and split by '|'
        print(line.title())
# Out:
# [
#
#     {
#
#         "Title": "Expected Power",
#
#         "Link": "Https://Codeforces.Com/Problemset/Problem/2020/E",
#
#         "Tags": "Dynamic Programming",
#
#         "Difficulty": "2000",
#
#         "Platform": "Codeforces"
#
#     },
#
#     {
#
#         "Title": "Connect The Dots",
#
#         "Link": "Https://Codeforces.Com/Problemset/Problem/2020/D",
#
#         "Tags": "Dynamic Programming",
#
#         "Difficulty": "1800",
#
#         "Platform": "Codeforces"
#
#     },
#
#     {
#
#         "Title": "Speedbreaker",
#
#         "Link": "Https://Codeforces.Com/Problemset/Problem/2018/B",
#
#         "Tags": "Dynamic Programming",
#
#         "Difficulty": "1900",
#
#         "Platform": "Codeforces"
#
#     },
#
#     {
#
#         "Title": "Sheriff'S Defense",
#
#         "Link": "Https://Codeforces.Com/Problemset/Problem/2014/F",
#
#         "Tags": "Dynamic Programming",
#
#         "Difficulty": "2000",
#
#         "Platform": "Codeforces"
#
#     },
#
# ...

# %%
import json
path = 'dataset/djson/implementation.json'

with open(path, 'r') as file:
    data = json.load(file)  # Parses the JSON file into a Python dictionary or list

# Print the data to see the content
print(data)
# Out:
# [{'title': 'Adjust The Presentation (Hard Version)', 'link': 'https://codeforces.com/problemset/problem/2021/C2', 'tags': 'Implemenation', 'difficulty': '1900', 'platform': 'codeforces'}, {'title': 'Bitwise Balancing', 'link': 'https://codeforces.com/problemset/problem/2020/C', 'tags': 'Implemenation', 'difficulty': '1400', 'platform': 'codeforces'}, {'title': 'Speedbreaker', 'link': 'https://codeforces.com/problemset/problem/2018/B', 'tags': 'Implemenation', 'difficulty': '1900', 'platform': 'codeforces'}, {'title': 'Cards Partition', 'link': 'https://codeforces.com/problemset/problem/2018/A', 'tags': 'Implemenation', 'difficulty': '1600', 'platform': 'codeforces'}, {'title': 'The Legend of Freya the Frog', 'link': 'https://codeforces.com/problemset/problem/2009/C', 'tags': 'Implemenation', 'difficulty': '1100', 'platform': 'codeforces'}, {'title': 'Alternating String', 'link': 'https://codeforces.com/problemset/problem/2008/E', 'tags': 'Implemenation', 'difficulty': '1500', 'platfo
# ...

# %%
type(data[0]['title'])
# Out:
# str

# %%
data[0]['title']
# Out:
# 'Adjust The Presentation (Hard Version)'

# %%
import json
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['dsa_problems']
collection = db['problems']

# %%
for document in data:
    collection.insert_one(document)

# %%
mongodb+srv://zihath04:RdidVjf10B5bAQyb@cluster0.tmx5z.mongodb.net/

# %%
from pymongo import MongoClient

# Replace with your MongoDB Atlas connection string
uri = "mongodb+srv://zihath04:samz04@cluster0.tmx5z.mongodb.net/"



# Establish a connection to MongoDB
client = MongoClient(uri)

# Access your specific database and collection
db = client['cloud_search']  # Replace with your actual database name
collection = db['problems']  # Replace with your collection name

# Test the connection by fetching documents
documents = collection.find()  # Retrieves all documents in the collection

# Display the documents
for doc in documents:
    print(doc)
# Out:
# {'_id': ObjectId('671f36a5826abbb1e6d9cd9d'), 'title': 'Expected Power', 'link': 'https://codeforces.com/problemset/problem/2020/E', 'tags': 'dynamic programming', 'difficulty': '2000', 'platform': 'codeforces'}
# {'_id': ObjectId('671f36a5826abbb1e6d9cd9e'), 'title': 'Connect the Dots', 'link': 'https://codeforces.com/problemset/problem/2020/D', 'tags': 'dynamic programming', 'difficulty': '1800', 'platform': 'codeforces'}
# {'_id': ObjectId('671f36a5826abbb1e6d9cd9f'), 'title': 'Speedbreaker', 'link': 'https://codeforces.com/problemset/problem/2018/B', 'tags': 'dynamic programming', 'difficulty': '1900', 'platform': 'codeforces'}
# {'_id': ObjectId('671f36a5826abbb1e6d9cda0'), 'title': "Sheriff's Defense", 'link': 'https://codeforces.com/problemset/problem/2014/F', 'tags': 'dynamic programming', 'difficulty': '2000', 'platform': 'codeforces'}
# ...

# %%
import pymongo
import json
from pymongo import MongoClient, InsertOne

client = pymongo.MongoClient("mongodb+srv://zihath04:samz04@cluster0.tmx5z.mongodb.net/")
db = client["search_engine"]
collection = db["problems"]
requesting = []

# %%
with open(r'C:\git repos\dsa_search_engine\dataset\djson\window.json') as file:
    new_data = json.load(file)

# %%
if isinstance(new_data, list):  # For an array of documents
    collection.insert_many(new_data)
else:  # For a single document
    collection.insert_one(new_data)

# %%
document_count = collection.count_documents({})

print("Number of documents:", document_count)
# Out:
# Number of documents: 1166
